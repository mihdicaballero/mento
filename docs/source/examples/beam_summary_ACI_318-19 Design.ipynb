# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mihdicaballero/mento/blob/main/docs/source/examples/beam_summary_ACI_318-19%20Design.ipynb)

# %%
# Google Colab does not ship mento, so install it when running there.
# Guarded so that building the documentation never shells out to pip.
import sys

if "google.colab" in sys.modules:
    # %pip install mento

# %% [markdown]
# # Beam summary design with ACI 318-19

# %% [markdown]
# **Create input dataframe**

# %% [markdown]
# This is an example creating the DataFrame directly in the cell but it's easier to load it from an Excel file, as is explained in the User Guide.
#
# This input has no rebar, since it's going to be designed by Mento

# %%
from mento import MPa
from mento import BeamSummary, Concrete_ACI_318_19, SteelBar
import pandas as pd

conc = Concrete_ACI_318_19(name="C25", f_c=25 * MPa)
steel = SteelBar(name="ADN 420", f_y=420 * MPa)
data = {
    "Label": ["", "V101", "V102", "V103", "V104"],
    "Comb.": ["", "ELU 1", "ELU 2", "ELU 3", "ELU 4"],
    "b": ["cm", 20, 20, 20, 20],
    "h": ["cm", 50, 50, 50, 50],
    "cc": ["mm", 25, 25, 25, 25],
    "Nx": ["kN", 0, 0, 0, 0],
    "Vz": ["kN", 20, -50, 100, 100],
    "My": ["kNm", 0, 35, 80, -80],
    "ns": ["", 0, 0, 0, 0],
    "dbs": ["mm", 0, 0, 0, 0],
    "sl": ["cm", 0, 0, 0, 0],
    "n1": ["", 0, 0, 0, 0],
    "db1": ["mm", 0, 0, 0, 0],
    "n2": ["", 0, 0, 0, 0.0],
    "db2": ["mm", 10, 16, 0, 0],
    "n3": ["", 0, 0.0, 20, 0.0],
    "db3": ["mm", 0, 0, 0, 0],
    "n4": ["", 0, 0.0, 0, 0.0],
    "db4": ["mm", 0, 0, 0, 0],
}
input_df = pd.DataFrame(data)

beam_summary = BeamSummary(concrete=conc, steel_bar=steel, beam_list=input_df)
# Beam summary input data
beam_summary.data
# Out:
#   Label  Comb.         b         h        cc       Nx         Vz           My  \
# 1  V101  ELU 1  20.00 cm  50.00 cm  25.00 mm  0.00 kN   20.00 kN    0.00 kN·m
# 2  V102  ELU 2  20.00 cm  50.00 cm  25.00 mm  0.00 kN  -50.00 kN   35.00 kN·m
# 3  V103  ELU 3  20.00 cm  50.00 cm  25.00 mm  0.00 kN  100.00 kN   80.00 kN·m
# 4  V104  ELU 4  20.00 cm  50.00 cm  25.00 mm  0.00 kN  100.00 kN  -80.00 kN·m
#
#    ns      dbs       sl  n1      db1  n2       db2  n3      db3  n4      db4
# 1   0  0.00 mm  0.00 cm   0  0.00 mm   0  10.00 mm   0  0.00 mm   0  0.00 mm
# 2   0  0.00 mm  0.00 cm   0  0.00 mm   0  16.00 mm   0  0.00 mm   0  0.00 mm
# 3   0  0.00 mm  0.00 cm   0  0.00 mm   0   0.00 mm  20  0.00 mm   0  0.00 mm
# 4   0  0.00 mm  0.00 cm   0  0.00 mm   0   0.00 mm   0  0.00 mm   0  0.00 mm

# %% [markdown]
# **Design all beams for shear and flexure**

# %%
beam_summary.design()
# Out:
# ✅ Beam design completed for all beams in Summary.
#   Label  Comb.         b         h        cc       Nx         Vz           My  \
# 0  V101  ELU 1  20.00 cm  50.00 cm  25.00 mm  0.00 kN   20.00 kN    0.00 kN·m
# 1  V102  ELU 2  20.00 cm  50.00 cm  25.00 mm  0.00 kN  -50.00 kN   35.00 kN·m
# 2  V103  ELU 3  20.00 cm  50.00 cm  25.00 mm  0.00 kN  100.00 kN   80.00 kN·m
# 3  V104  ELU 4  20.00 cm  50.00 cm  25.00 mm  0.00 kN  100.00 kN  -80.00 kN·m
#
#    ns       dbs        sl  n1       db1  n2       db2  n3 db3  n4 db4
# 0   1  10.00 mm  23.00 cm   2  12.00 mm   0         0   0   0   0   0
# 1   1  10.00 mm  23.00 cm   2  12.00 mm   1  10.00 mm   0   0   0   0
# 2   1  10.00 mm  11.00 cm   2  16.00 mm   1  12.00 mm   0   0   0   0
# 3   1  10.00 mm  11.00 cm   2  16.00 mm   1  12.00 mm   0   0   0   0

# %% [markdown]
# **Check all beams for shear and flexure with current design**

# %%
beam_summary.check()
# Out:
#    Beam   b   h  cc     As,top     As,bot        Av As,req,top As,req,bot  \
# 0        cm  cm  mm                                      cm²/m      cm²/m
# 1  V101  20  50  25          -       2Ø12  1eØ10/23        0.0        1.8
# 2  V102  20  50  25          -  2Ø12+1Ø10  1eØ10/23        0.0        2.7
# 3  V103  20  50  25          -  2Ø16+1Ø12  1eØ10/11        0.0        4.9
# 4  V104  20  50  25  2Ø16+1Ø12       2Ø12  1eØ10/11        4.9        0.0
#
#   Av,req  ... DCRb,top DCRb,bot   DCRv    Mu     Vu   Nu ØMn,top ØMn,bot  \
# 0  cm²/m  ...                            kNm     kN   kN     kNm     kNm
# 1    0.0  ...      0.0      0.0  0.161   0.0   20.0  0.0     0.0    38.3
# 2    0.0  ...      0.0    0.684  0.393  35.0  -50.0  0.0     0.0    51.2
# 3   2.89  ...      0.0    0.951  0.379  80.0  100.0  0.0     0.0    84.1
# 4   2.89  ...    0.951      0.0  0.379 -80.0  100.0  0.0    84.1    38.3
#
#      ØVn Ok?
# 0     kN
# 1  124.5   ✅
# 2  127.3   ✅
# 3  264.1   ✅
# 4  264.1   ✅
#
# [5 rows x 21 columns]

# %% [markdown]
# **Export design results to excel**

# %%
beam_summary.export_design("Beam-Design.xlsx")
# Out:
# ✅ Beam design exported to Beam-Design.xlsx

# %% [markdown]
# At this point, you could open the Excel file, edit the proposed design, import it and check again
#
# For this example, let's modify V101 stirrup spacing to 15 cm, V103 longitudinal rebar to 2Ø16+1Ø16 and V104 to 2Ø20.

# %%
beam_summary.import_design("Beam-Design.xlsx")
# Out:
# ✅ Beam design imported and summary data updated.

# %% [markdown]
# Let's print the data to see the updated beam summary.

# %%
beam_summary.data
# Out:
#   Label  Comb.         b         h        cc       Nx         Vz           My  \
# 1  V101  ELU 1  20.00 cm  50.00 cm  25.00 mm  0.00 kN   20.00 kN    0.00 kN·m
# 2  V102  ELU 2  20.00 cm  50.00 cm  25.00 mm  0.00 kN  -50.00 kN   35.00 kN·m
# 3  V103  ELU 3  20.00 cm  50.00 cm  25.00 mm  0.00 kN  100.00 kN   80.00 kN·m
# 4  V104  ELU 4  20.00 cm  50.00 cm  25.00 mm  0.00 kN  100.00 kN  -80.00 kN·m
#
#    ns       dbs        sl  n1       db1  n2       db2  n3      db3  n4  \
# 1   1  10.00 mm  23.00 cm   2  12.00 mm   0   0.00 mm   0  0.00 mm   0
# 2   1  10.00 mm  23.00 cm   2  12.00 mm   1  10.00 mm   0  0.00 mm   0
# 3   1  10.00 mm  11.00 cm   2  16.00 mm   1  12.00 mm   0  0.00 mm   0
# 4   1  10.00 mm  11.00 cm   2  16.00 mm   1  12.00 mm   0  0.00 mm   0
#
#        db4
# 1  0.00 mm
# 2  0.00 mm
# 3  0.00 mm
# 4  0.00 mm

# %% [markdown]
# Perform the check again, with the new rebar.

# %%
beam_summary.check()
# Out:
#    Beam   b   h  cc     As,top     As,bot        Av As,req,top As,req,bot  \
# 0        cm  cm  mm                                      cm²/m      cm²/m
# 1  V101  20  50  25        2Ø8       2Ø12  1eØ10/23        0.0        1.8
# 2  V102  20  50  25        2Ø8  2Ø12+1Ø10  1eØ10/23        0.0        2.7
# 3  V103  20  50  25        2Ø8  2Ø16+1Ø12  1eØ10/11        0.0        4.9
# 4  V104  20  50  25  2Ø16+1Ø12        2Ø8  1eØ10/11        4.9        0.0
#
#   Av,req  ... DCRb,top DCRb,bot   DCRv    Mu     Vu   Nu ØMn,top ØMn,bot  \
# 0  cm²/m  ...                            kNm     kN   kN     kNm     kNm
# 1    0.0  ...      0.0      0.0  0.161   0.0   20.0  0.0    17.3    38.3
# 2    0.0  ...      0.0    0.684  0.393  35.0  -50.0  0.0    17.3    51.2
# 3   2.89  ...      0.0    0.951  0.379  80.0  100.0  0.0    17.3    84.1
# 4   2.89  ...    0.951      0.0  0.379 -80.0  100.0  0.0    84.1    17.3
#
#      ØVn Ok?
# 0     kN
# 1  124.5   ✅
# 2  127.3   ✅
# 3  264.1   ✅
# 4  264.1   ✅
#
# [5 rows x 21 columns]

# %% [markdown]
# You could check the specific shear and flexure results following the Beam Summary Check example.

# %% [markdown]
# **Export results to Word**

# %%
beam_summary.results_detailed_doc(index=1)
# Out:
# ✅ Results exported to Beam_Summary_ACI 318-19.docx

# %% [markdown]
# **Export results to Excel**

# %%
beam_summary.check().to_excel("Beam_summary_results.xlsx", index=False)
